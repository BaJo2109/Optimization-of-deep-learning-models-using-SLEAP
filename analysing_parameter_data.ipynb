# %%
import pandas as pd

# Load the SLEAP output CSV files for filter tested models
filter_tested_12a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_12\filter_12.000_video0030 25-01-24 19-32-29.analysis.csv')
filter_tested_12b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_12\filter_12.001_video0030 25-01-24 19-53-50.analysis.csv')

# Combine the dataframes if needed
combined_filter_tested_12 = pd.concat([filter_tested_12a, filter_tested_12b], ignore_index=True)

filter_tested_18a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_18\filter_18.000_video0030 25-01-24 19-32-29.analysis.csv')
filter_tested_18b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_18\filter_18.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_filter_tested_18 = pd.concat([filter_tested_18a, filter_tested_18b], ignore_index=True)

filter_tested_24a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_24\filter_24.000_video0030 25-01-24 19-32-29.analysis.csv')
filter_tested_24b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_24\filter_24.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_filter_tested_24 = pd.concat([filter_tested_24a, filter_tested_24b], ignore_index=True)

filter_tested_48a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_48\filter_48.000_video0030 25-01-24 19-32-29.analysis.csv')
filter_tested_48b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\filter_48\filter_48.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_filter_tested_48 = pd.concat([filter_tested_48a, filter_tested_48b], ignore_index=True)

# Display the first few rows of the combined dataframe
print('Filter 12',combined_filter_tested_12.head())
print('Filter 18',combined_filter_tested_18.head())
print('Filter 24',combined_filter_tested_24.head())
print('Filter 48',combined_filter_tested_48.head())
# Out:
# Filter 12    track  frame_idx  instance.score      nose.x      nose.y  nose.score  \
# 0    NaN          0             NaN  638.137768  613.819519         NaN
# 1    NaN        127        1.028822  426.477295  335.126770    0.816997
# 2    NaN        200        0.935863  467.160278  105.191917    0.661416
# 3    NaN        434             NaN  502.131635  145.318571         NaN
# 4    NaN        878        1.004447  434.316040  471.475983    0.267315
#
#        neck.x      neck.y  neck.score  tail_base.x  tail_base.y  \
# 0  636.860779  576.403442         NaN   646.033764   500.912000
# 1  434.642365  367.405884    0.964584   458.234283   417.962677
# 2  450.847443  129.540466    0.978748   426.879517   179.428101
# 3  519.162618  121.397954         NaN   591.427315   118.051653
# 4  433.949707  462.109650    0.936237   450.537964   403.811279
#
#    tail_base.score
# 0              NaN
# 1         0.512697
# 2         0.758033
# 3              NaN
# 4         0.582575
# ...

# %%
combined_filter_tested_48
# Out:
#      track  frame_idx  instance.score      nose.x      nose.y  nose.score  \
# 0      NaN          0             NaN  638.137768  613.819519         NaN
# 1      NaN        127        0.965045  437.930511  329.580017    0.561238
# 2      NaN        200        1.002938  466.643585  105.595474    0.816859
# 3      NaN        434             NaN  502.131635  145.318571         NaN
# 4      NaN        878        0.995399  427.382477  481.198029    0.397312
# ..     ...        ...             ...         ...         ...         ...
# 194    NaN      25509             NaN         NaN         NaN         NaN
# 195    NaN      25525             NaN         NaN         NaN         NaN
# 196    NaN      25851        1.027768  839.222839  330.228149    0.817493
# 197    NaN      26726             NaN  594.074280  224.508301         NaN
# 198    NaN      26958        1.025081  488.290131  480.549225    0.620169
#
#          neck.x      neck.y  neck.score  tail_base.x  tail_base.y  \
# ...

# %%
#Count number of instance.scores in filter tested 48
print(combined_filter_tested_48['instance.score'].value_counts())
# Out:
# instance.score
# 0.965045    1
# 1.002938    1
# 0.995399    1
# 1.006546    1
# 1.011199    1
#            ..
# 0.895944    1
# 0.939803    1
# 1.035684    1
# 1.027768    1
# 1.025081    1
# Name: count, Length: 100, dtype: int64

# %%
#Load the SLEAP output CSV files for filter tested models
learning_rate_00001a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\\parameter_CSV\learning_rate_0.0001\learning_rate_0,0001.000_video0030 25-01-24 19-32-29.analysis.csv')
learning_rate_00001b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\learning_rate_0.0001\learning_rate_0,0001.001_video0030 25-01-24 19-53-50.analysis.csv')

# Combine the dataframes if needed
combined_learning_rate_00001 = pd.concat([learning_rate_00001a, learning_rate_00001b], ignore_index=True)

learning_rate_0001a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\learning_rate_0.001\learning_rate_0,001.000_video0030 25-01-24 19-32-29.analysis.csv')
learning_rate_0001b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\learning_rate_0.001\learning_rate_0,001.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_learning_rate_0001 = pd.concat([learning_rate_0001a, learning_rate_0001b], ignore_index=True)

learning_rate_00005a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\learning_rate_0.0005\learning_rate_0,0005.000_video0030 25-01-24 19-32-29.analysis.csv')
learning_rate_00005b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\learning_rate_0.0005\learning_rate_0,0005.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_learning_rate_000005 = pd.concat([learning_rate_00005a, learning_rate_00005b], ignore_index=True)

learning_rate_000005a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\learning_rate_0.00005\learning_rate_0,00005.000_video0030 25-01-24 19-32-29.analysis.csv')
learning_rate_000005b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\learning_rate_0.00005\learning_rate_0,00005.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_learning_rate_00005 = pd.concat([learning_rate_000005a, learning_rate_000005b], ignore_index=True)

# Display the first few rows of the combined dataframe
print('learning_rate_00001',combined_learning_rate_00001.head())
print('learning_rate_0001',combined_learning_rate_0001.head())
print('learning_rate_000005',combined_learning_rate_000005.head())
print('learning_rate_00005',combined_learning_rate_00005.head())
# Out:
# learning_rate_00001    track  frame_idx  instance.score      nose.x      nose.y  nose.score  \
# 0    NaN          0             NaN  638.137768  613.819519         NaN
# 1    NaN        127        1.035072  429.994812  335.628479    0.896061
# 2    NaN        200        0.950895  473.763855  104.860214    0.863789
# 3    NaN        434             NaN  502.131635  145.318571         NaN
# 4    NaN        878        0.974754  442.496826  480.307007    0.592683
#
#        neck.x      neck.y  neck.score  tail_base.x  tail_base.y  \
# 0  636.860779  576.403442         NaN   646.033764   500.912000
# 1  445.849731  368.081055    1.013411   446.410461   419.109131
# 2  449.913208  129.356415    0.972050   426.770660   179.304688
# 3  519.162618  121.397954         NaN   591.427315   118.051653
# 4  434.744049  448.821899    1.004857   458.086243   391.079376
#
#    tail_base.score
# 0              NaN
# 1         0.503130
# 2         0.749122
# 3              NaN
# 4         0.719734
# ...

# %%
#Load the SLEAP output CSV files for filter tested models
output_stride_2a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_2\output_stride_2.000_video0030 25-01-24 19-32-29.analysis.csv')
output_stride_2b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_2\output_stride_2.001_video0030 25-01-24 19-53-50.analysis.csv')

# Combine the dataframes if needed
combined_output_stride_2 = pd.concat([output_stride_2a, output_stride_2b], ignore_index=True)


output_stride_4a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_4\Output_stride_4.000_video0030 25-01-24 19-32-29.analysis.csv')
output_stride_4b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_4\Output_stride_4.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_output_stride_4 = pd.concat([output_stride_4a, output_stride_4b], ignore_index=True)

output_stride_8a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_8\output_stride_8.000_video0030 25-01-24 19-32-29.analysis.csv')
output_stride_8b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_8\output_stride_8.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_output_stride_8 = pd.concat([output_stride_8a, output_stride_8b], ignore_index=True)

output_stride_16a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_16\output_stride_16.000_video0030 25-01-24 19-32-29.analysis.csv')
output_stride_16b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\output_stride_16\output_stride_16.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_output_stride_16 = pd.concat([output_stride_16a, output_stride_16b], ignore_index=True)



# Display the first few rows of the combined dataframe
print('output_stride_2',combined_output_stride_2.head())
print('output_stride_4',combined_output_stride_4.head())
print('output_stride_8',combined_output_stride_8.head())
print('output_stride_16',combined_output_stride_16.head())
# Out:
# output_stride_2    track  frame_idx  instance.score      nose.x      nose.y  nose.score  \
# 0    NaN        127        0.817633  437.937378  332.207458    0.622944
# 1    NaN        200        0.904787  471.293732  104.611572    0.451299
# 2    NaN        878        0.935393  442.327118  488.173035    0.415698
# 3    NaN       3043        0.896709  536.410461  173.838013    0.495842
# 4    NaN       3370        0.848920  452.963531  104.642159    0.704088
#
#        neck.x      neck.y  neck.score  tail_base.x  tail_base.y  \
# 0  440.245850  372.082825    0.898469          NaN          NaN
# 1  448.730652  132.535995    0.937242   438.811035   192.950928
# 2  440.217255  452.186981    0.885978          NaN          NaN
# 3  504.141724  183.985641    0.923906   441.999146   202.082535
# 4  456.906342  140.492676    0.920837          NaN          NaN
#
#    tail_base.score
# 0         0.000000
# 1         0.329863
# 2         0.000000
# 3         0.340948
# 4         0.000000
# ...

# %%
import pandas as pd

epoch_25a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_25\epoch_25.000_video0030 25-01-24 19-32-29.analysis.csv')
epoch_25b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_25\epoch_25.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_epoch_25 = pd.concat([epoch_25a, epoch_25b], ignore_index=True)

epoch_50a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_50\epoch_50.000_video0030 25-01-24 19-32-29.analysis.csv')
epoch_50b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_50\epoch_50.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_epoch_50 = pd.concat([epoch_50a, epoch_50b], ignore_index=True)

epoch_100a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_100\epoch_100.000_video0030 25-01-24 19-32-29.analysis.csv')
epoch_100b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_100\epoch_100.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_epoch_100 = pd.concat([epoch_100a, epoch_100b], ignore_index=True)

epoch_200a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_200\epoch_200.000_video0030 25-01-24 19-32-29.analysis.csv')
epoch_200b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\epoch_200\epoch_200.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_epoch_200 = pd.concat([epoch_200a, epoch_200b], ignore_index=True)

print('epoch_25', combined_epoch_25.head())
print('epoch_50', combined_epoch_50.head())
print('epoch_100', combined_epoch_100.head())
print('epoch_200', combined_epoch_200.head())
# Out:
# epoch_25    track  frame_idx  instance.score      nose.x      nose.y  nose.score  \
# 0    NaN          0             NaN  638.137768  613.819519         NaN
# 1    NaN        127        0.977827  446.573059  336.323608    0.524064
# 2    NaN        200        0.984955  458.693054   98.681656    0.501189
# 3    NaN        434             NaN  502.131635  145.318571         NaN
# 4    NaN        878        0.951419  443.464417  487.373444    0.592837
#
#        neck.x      neck.y  neck.score  tail_base.x  tail_base.y  \
# 0  636.860779  576.403442         NaN   646.033764   500.912000
# 1  446.422119  368.192474    0.951809   438.378113   418.538757
# 2  449.986298  130.632050    1.018098   424.920593   180.052094
# 3  519.162618  121.397954         NaN   591.427315   118.051653
# 4  435.440399  461.563721    0.829515   458.332703   404.276550
#
#    tail_base.score
# 0              NaN
# 1         0.508419
# 2         0.833921
# 3              NaN
# 4         0.558172
# ...

# %%
#import batch size data
import pandas as pd

batch_size_2a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_2\batch_2.000_video0030 25-01-24 19-32-29.analysis.csv')
batch_size_2b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_2\batch_2.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_batch_size_2 = pd.concat([batch_size_2a, batch_size_2b], ignore_index=True)

batch_size_4a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_4\batch_4.000_video0030 25-01-24 19-32-29.analysis.csv')
batch_size_4b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_4\batch_4.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_batch_size_4 = pd.concat([batch_size_4a, batch_size_4b], ignore_index=True)

batch_size_8a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_8\batch_8.000_video0030 25-01-24 19-32-29.analysis.csv')
batch_size_8b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_8\batch_8.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_batch_size_8 = pd.concat([batch_size_8a, batch_size_8b], ignore_index=True)    

batch_size_16a = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_16\batch_16.000_video0030 25-01-24 19-32-29.analysis.csv')
batch_size_16b = pd.read_csv(r'C:\Users\jrall\Desktop\Bachelorarbeit\Ergebnisse\Parameter\parameter_CSV\batchsize_16\batch_16.001_video0030 25-01-24 19-53-50.analysis.csv')
# Combine the dataframes if needed
combined_batch_size_16 = pd.concat([batch_size_16a, batch_size_16b], ignore_index=True)

# %%
#Making 4 diifferent histograms for instance for filter tested models
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 4))
plt.subplot(1, 4, 1)
plt.hist(combined_filter_tested_12['instance.score'], bins=100, alpha=0.7, color='red')
plt.title('Filter 12')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 12)
plt.xlim(0,2)
plt.subplot(1, 4, 2)
plt.hist(combined_filter_tested_18['instance.score'], bins=100, alpha=0.7, color='blue')
plt.title('Filter 18')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 12)
plt.xlim(0,2)
plt.subplot(1, 4, 3)
plt.hist(combined_filter_tested_24['instance.score'], bins=100, alpha=0.7, color='purple')
plt.title('Filter 24')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 12)
plt.xlim(0,2)
plt.subplot(1, 4, 4)
plt.hist(combined_filter_tested_48['instance.score'], bins=100, alpha=0.7, color='green')
plt.title('Filter 48')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 12)
plt.xlim(0,2)
plt.show()

# %%
#Making 4 different histograms each side by side for instance for learning rate tested models
#The y-axis is 50 ticks long in all subplots
#The x-axis range goes from 0.4 to 1.2
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 5))

plt.subplot(1, 4, 2)
plt.hist(combined_learning_rate_00001['instance.score'], bins=10, alpha=0.7, color='blue')
plt.title('Learning Rate 10^(-4)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)


plt.subplot(1, 4, 4)
plt.hist(combined_learning_rate_0001['instance.score'], bins=10, alpha=0.7, color='green')
plt.title('Learning Rate 10^(-3)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)

plt.subplot(1, 4, 1)
plt.hist(combined_learning_rate_000005['instance.score'], bins=10, alpha=0.7, color='red')
plt.title('Learning Rate 5x10^(-5)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)

plt.subplot(1, 4, 3)
plt.hist(combined_learning_rate_00005['instance.score'], bins=10, alpha=0.7, color='purple')
plt.title('Learning Rate 5x10^(-4)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)

plt.suptitle('Histograms of Instances for Different Learning Rate Tested Models')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
#Making 3 different histograms for instance for output stride tested models in subplots
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 5))
plt.subplot(1, 4, 1)
plt.hist(combined_output_stride_2['instance.score'], bins=10, alpha=0.7, color='red')
plt.title('Output Stride 2')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)


plt.subplot(1, 4, 2)
plt.hist(combined_output_stride_4['instance.score'], bins=10, alpha=0.7, color='blue')
plt.title('Output Stride 4')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)

plt.subplot(1, 4, 3)

plt.hist(combined_output_stride_8['instance.score'], bins=10, alpha=0.7, color='purple')
plt.title('Output Stride 8')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)

plt.subplot(1, 4, 4)

plt.hist(combined_output_stride_16['instance.score'], bins=10, alpha=0.7, color='green')
plt.title('Output Stride 16')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.show()

# %%
#Making 4 different histograms for instance for epoch tested models
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 5))
plt.subplot(1, 4, 1)
plt.hist(combined_epoch_25['instance.score'], bins=10, alpha=0.7, color='red')
plt.title('Epochs 25')  
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)

plt.subplot(1, 4, 2)
plt.hist(combined_epoch_50['instance.score'], bins=10, alpha=0.7, color='blue')
plt.title('Epochs 50')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.subplot(1, 4, 3)
plt.hist(combined_epoch_100['instance.score'], bins=10, alpha=0.7, color='purple')
plt.title('Epochs 100')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)

plt.subplot(1, 4, 4)
plt.hist(combined_epoch_200['instance.score'], bins=10, alpha=0.7, color='green')
plt.title('Epochs 200')  
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.show()

# %%
# Building a plot where all 4 Parameters with their 4 values are shown to compare which is the best performing one
# Putting all histograms together in one figure for learning rate,filters, epoch and output stride

import matplotlib.pyplot as plt
plt.figure(figsize=(16, 16))

plt.subplot(1, 4, 1)
#Filter tested models
plt.hist(combined_filter_tested_12['instance.score'], bins=10, alpha=0.7, color='red')
plt.title('Filter 12')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(1, 4, 2)
plt.hist(combined_filter_tested_18['instance.score'], bins=10, alpha=0.7, color='blue')
plt.title('Filter 18')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(1, 4, 3)
plt.hist(combined_filter_tested_24['instance.score'], bins=10, alpha=0.7, color='purple')
plt.title('Filter 24')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(1, 4, 4)
plt.hist(combined_filter_tested_48['instance.score'], bins=10, alpha=0.7, color='green')
plt.title('Filter 48')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

#Learning rate tested models in the second row

plt.subplot(2, 4, 5)
plt.hist(combined_learning_rate_00001['instance.score'], bins=10, alpha=0.7, color='blue')
plt.title('Learning Rate 10^(-4)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()


plt.subplot(2, 4, 6)
plt.hist(combined_learning_rate_0001['instance.score'], bins=10, alpha=0.7, color='green')
plt.title('Learning Rate 10^(-3)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(2, 4, 7)
plt.hist(combined_learning_rate_000005['instance.score'], bins=10, alpha=0.7, color='red')
plt.title('Learning Rate 5x10^(-5)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(2, 4, 8)
plt.hist(combined_learning_rate_00005['instance.score'], bins=10, alpha=0.7, color='purple')
plt.title('Learning Rate 5x10^(-4)')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

#Output stride tested models in the third row

plt.subplot(3, 4, 9)
plt.hist(combined_output_stride_2['instance.score'], bins=10, alpha=0.7, color='red')
plt.title('Output Stride 2')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(3, 4, 10)
plt.hist(combined_output_stride_4['instance.score'], bins=10, alpha=0.7, color='blue')
plt.title('Output Stride 4')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(3, 4, 11)
plt.hist(combined_output_stride_8['instance.score'], bins=10, alpha=0.7, color='purple')
plt.title('Output Stride 8')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(3, 4, 12)
plt.hist(combined_output_stride_16['instance.score'], bins=10, alpha=0.7, color='green')
plt.title('Output Stride 16')   
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

#Epoch tested models in the fourth row
plt.subplot(4, 4, 13)
plt.hist(combined_epoch_25['instance.score'], bins=10, alpha=0.7, color='red')
plt.title('Epochs 25')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(4, 4, 14)
plt.hist(combined_epoch_50['instance.score'], bins=10, alpha=0.7, color='blue')
plt.title('Epochs 50')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(4, 4, 15)
plt.hist(combined_epoch_100['instance.score'], bins=10, alpha=0.7, color='purple')
plt.title('Epochs 100')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.subplot(4, 4, 16)
plt.hist(combined_epoch_200['instance.score'], bins=10, alpha=0.7, color='green')
plt.title('Epochs 200')
plt.xlabel('Instance Value')
plt.ylabel('Frequency')
plt.ylim(0, 50)
plt.xlim(0.4, 1.2)
plt.tight_layout()

plt.show()
# Out:
# C:\Users\jrall\AppData\Local\Temp\ipykernel_6048\700012533.py:92: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout()
# C:\Users\jrall\AppData\Local\Temp\ipykernel_6048\700012533.py:101: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout()
# C:\Users\jrall\AppData\Local\Temp\ipykernel_6048\700012533.py:110: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout()
# C:\Users\jrall\AppData\Local\Temp\ipykernel_6048\700012533.py:119: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(4, 4, figsize=(16, 16), sharex=True, sharey=True)

# ---------- Row 1: Filters ----------
filters = [
    (combined_filter_tested_12, 'Filter 12', 'red'),
    (combined_filter_tested_18, 'Filter 18', 'blue'),
    (combined_filter_tested_24, 'Filter 24', 'purple'),
    (combined_filter_tested_48, 'Filter 48', 'green'),
]

for ax, (data, title, color) in zip(axes[0], filters):
    ax.hist(data['instance.score'], bins=10, alpha=0.7, color=color)
    ax.set_title(title)

# ---------- Row 2: Learning Rate ----------
learning_rates = [
    (combined_learning_rate_00001, 'LR 1e-4', 'red'),
    (combined_learning_rate_0001,  'LR 1e-3', 'blue'),
    (combined_learning_rate_000005,'LR 5e-5', 'purple'),
    (combined_learning_rate_00005, 'LR 5e-4', 'green'),
]

for ax, (data, title, color) in zip(axes[1], learning_rates):
    ax.hist(data['instance.score'], bins=10, alpha=0.7, color=color)
    ax.set_title(title)

# ---------- Row 3: Output Stride ----------
output_strides = [
    (combined_output_stride_2,  'OS 2', 'red'),
    (combined_output_stride_4,  'OS 4', 'blue'),
    (combined_output_stride_8,  'OS 8', 'purple'),
    (combined_output_stride_16, 'OS 16', 'green'),
]

for ax, (data, title, color) in zip(axes[2], output_strides):
    ax.hist(data['instance.score'], bins=10, alpha=0.7, color=color)
    ax.set_title(title)

# ---------- Row 4: Epochs ----------
epochs = [
    (combined_epoch_25,  'Epochs 25', 'red'),
    (combined_epoch_50,  'Epochs 50', 'blue'),
    (combined_epoch_100, 'Epochs 100', 'purple'),
    (combined_epoch_200, 'Epochs 200', 'green'),
]

for ax, (data, title, color) in zip(axes[3], epochs):
    ax.hist(data['instance.score'], bins=10, alpha=0.7, color=color)
    ax.set_title(title)

# ---------- Global formatting ----------
for ax in axes.flat:
    ax.set_xlim(0.4, 1.2)
    ax.set_ylim(0, 50)
    ax.set_xlabel('Instance Value')
    ax.set_ylabel('Frequency')

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(14, 10), sharey=True)

# ---------- Filters ----------
axes[0, 0].boxplot([
    combined_filter_tested_12['instance.score'].dropna(),
    combined_filter_tested_18['instance.score'].dropna(),
    combined_filter_tested_24['instance.score'].dropna(),
    combined_filter_tested_48['instance.score'].dropna()
], tick_labels=['12', '18', '24', '48'], showfliers=True)

axes[0, 0].set_title('Filters')
axes[0, 0].set_xlabel('Filter Size')

# ---------- Learning Rate ----------
axes[0, 1].boxplot([
    combined_learning_rate_00001['instance.score'].dropna(),
    combined_learning_rate_0001['instance.score'].dropna(),
    combined_learning_rate_000005['instance.score'].dropna(),
    combined_learning_rate_00005['instance.score'].dropna()
], tick_labels=['1e-4', '1e-3', '5e-5', '5e-4'], showfliers=True)

axes[0, 1].set_title('Learning Rate')

# ---------- Output Stride ----------
axes[1, 0].boxplot([
    combined_output_stride_2['instance.score'].dropna(),
    combined_output_stride_4['instance.score'].dropna(),
    combined_output_stride_8['instance.score'].dropna(),
    combined_output_stride_16['instance.score'].dropna()
], tick_labels=['2', '4', '8', '16'], showfliers=True)

axes[1, 0].set_title('Output Stride')
axes[1, 0].set_xlabel('Stride')

# ---------- Epochs ----------
axes[1, 1].boxplot([
    combined_epoch_25['instance.score'].dropna(),
    combined_epoch_50['instance.score'].dropna(),
    combined_epoch_100['instance.score'].dropna(),
    combined_epoch_200['instance.score'].dropna()
], tick_labels=['25', '50', '100', '200'], showfliers=True)

axes[1, 1].set_title('Epochs')

# ---------- Global formatting ----------
for ax in axes.flat:
    ax.set_ylabel('Instance Value')
    ax.set_ylim(0.4, 1.2)
    ax.grid(axis='y', linestyle='--', alpha=0.4)

fig.suptitle(
    'Hyperparameter Comparison using Boxplots',
    fontsize=16
)

fig.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
print(combined_filter_tested_12['instance.score'].count())
# Out:
# 100

# %%
import numpy as np
import matplotlib.pyplot as plt

mean_filter_12 =np.mean(combined_filter_tested_12['instance.score'].dropna())
SEM_filter_12 = np.std(combined_filter_tested_12['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_filter_tested_12['instance.score'].count())

mean_filter_18 =np.mean(combined_filter_tested_18['instance.score'].dropna())
SEM_filter_18 = np.std(combined_filter_tested_18['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_filter_tested_18['instance.score'].count())

mean_filter_24 =np.mean(combined_filter_tested_24['instance.score'].dropna())
SEM_filter_24 = np.std(combined_filter_tested_24['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_filter_tested_24['instance.score'].count())

mean_filter_48 =np.mean(combined_filter_tested_48['instance.score'].dropna())
SEM_filter_48 = np.std(combined_filter_tested_48['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_filter_tested_48['instance.score'].count())

mean_learning_rate_00001 =np.mean(combined_learning_rate_00001['instance.score'].dropna())
SEM_learning_rate_00001 = np.std(combined_learning_rate_00001['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_learning_rate_00001['instance.score'].count())

mean_learning_rate_0001 =np.mean(combined_learning_rate_0001['instance.score'].dropna())
SEM_learning_rate_0001 = np.std(combined_learning_rate_0001['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_learning_rate_0001['instance.score'].count())

mean_learning_rate_000005 =np.mean(combined_learning_rate_000005['instance.score'].dropna())
SEM_learning_rate_000005 = np.std(combined_learning_rate_000005['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_learning_rate_000005['instance.score'].count())

mean_learning_rate_00005 =np.mean(combined_learning_rate_00005['instance.score'].dropna())
SEM_learning_rate_00005 = np.std(combined_learning_rate_00005['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_learning_rate_00005['instance.score'].count())

mean_output_stride_2 =np.mean(combined_output_stride_2['instance.score'].dropna())
SEM_output_stride_2 = np.std(combined_output_stride_2['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_output_stride_2['instance.score'].count())

mean_output_stride_4 =np.mean(combined_output_stride_4['instance.score'].dropna())
SEM_output_stride_4 = np.std(combined_output_stride_4['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_output_stride_4['instance.score'].count())

mean_output_stride_8 =np.mean(combined_output_stride_8['instance.score'].dropna())
SEM_output_stride_8 = np.std(combined_output_stride_8['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_output_stride_8['instance.score'].count())

mean_output_stride_16 =np.mean(combined_output_stride_16['instance.score'].dropna())
SEM_output_stride_16 = np.std(combined_output_stride_16['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_output_stride_16['instance.score'].count())

mean_epoch_25 =np.mean(combined_epoch_25['instance.score'].dropna())
SEM_epoch_25 = np.std(combined_epoch_25['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_epoch_25['instance.score'].count())

mean_epoch_50 =np.mean(combined_epoch_50['instance.score'].dropna())
SEM_epoch_50 = np.std(combined_epoch_50['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_epoch_50['instance.score'].count())

mean_epoch_100 =np.mean(combined_epoch_100['instance.score'].dropna())
SEM_epoch_100 = np.std(combined_epoch_100['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_epoch_100['instance.score'].count())

mean_epoch_200 =np.mean(combined_epoch_200['instance.score'].dropna())
SEM_epoch_200 = np.std(combined_epoch_200['instance.score'].dropna(), ddof=1)/ np.sqrt(combined_epoch_200['instance.score'].count())

# %%
# Print means and SEMs
print("Filter Tested Models:")
print(f"Filter 12 - Mean: {mean_filter_12}, SEM: {SEM_filter_12}")
print(f"Filter 18 - Mean: {mean_filter_18}, SEM: {SEM_filter_18}")
print(f"Filter 24 - Mean: {mean_filter_24}, SEM: {SEM_filter_24}")
print(f"Filter 48 - Mean: {mean_filter_48}, SEM: {SEM_filter_48}")

print("Learning Rate Tested Models:")
print(f"Learning Rate 1e-4 - Mean: {mean_learning_rate_00001}, SEM: {SEM_learning_rate_00001}")
print(f"Learning Rate 1e-3 - Mean: {mean_learning_rate_0001}, SEM: {SEM_learning_rate_0001}")
print(f"Learning Rate 5e-5 - Mean: {mean_learning_rate_000005}, SEM: {SEM_learning_rate_000005}")
print(f"Learning Rate 5e-4 - Mean: {mean_learning_rate_00005}, SEM: {SEM_learning_rate_00005}")

print("Output Stride Tested Models:")
print(f"Output Stride 2 - Mean: {mean_output_stride_2}, SEM: {SEM_output_stride_2}")
print(f"Output Stride 4 - Mean: {mean_output_stride_4}, SEM: {SEM_output_stride_4}")
print(f"Output Stride 8 - Mean: {mean_output_stride_8}, SEM: {SEM_output_stride_8}")
print(f"Output Stride 16 - Mean: {mean_output_stride_16}, SEM: {SEM_output_stride_16}")

print("Epoch Tested Models:")
print(f"Epochs 25 - Mean: {mean_epoch_25}, SEM: {SEM_epoch_25}")
print(f"Epochs 50 - Mean: {mean_epoch_50}, SEM: {SEM_epoch_50}")
print(f"Epochs 100 - Mean: {mean_epoch_100}, SEM: {SEM_epoch_100}")
print(f"Epochs 200 - Mean: {mean_epoch_200}, SEM: {SEM_epoch_200}")
# Out:
# Filter Tested Models:
# Filter 12 - Mean: 0.9646140468120575, SEM: 0.010090457262852109
# Filter 18 - Mean: 0.9704058808088303, SEM: 0.008210800905362652
# Filter 24 - Mean: 0.9559246963262558, SEM: 0.007336157764508071
# Filter 48 - Mean: 0.9829024136066437, SEM: 0.005078197827643915
# Learning Rate Tested Models:
# Learning Rate 1e-4 - Mean: 0.9738875293731689, SEM: 0.00871544838224369
# Learning Rate 1e-3 - Mean: 1.0062351775169374, SEM: 0.008221741140875328
# Learning Rate 5e-5 - Mean: 0.8850602126121521, SEM: 0.009955426444240138
# Learning Rate 5e-4 - Mean: 0.9805079303225692, SEM: 0.00426350451637063
# Output Stride Tested Models:
# Output Stride 2 - Mean: 0.8318889104958737, SEM: 0.013896850891611088
# Output Stride 4 - Mean: 0.9671996402740478, SEM: 0.0055175618463889995
# Output Stride 8 - Mean: 0.9738875293731689, SEM: 0.00871544838224369
# Output Stride 16 - Mean: 0.9046177373578151, SEM: 0.013481300495646662
# Epoch Tested Models:
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt




# --- Calculate mean and SEM ---
mean_val = np.mean(data)
sem_val = np.std(data, ddof=1) / np.sqrt(len(data))

# --- Scatter plot with jitter ---
x_jitter = np.random.normal(0, 0.05, size=len(data))  # small horizontal jitter
plt.scatter(np.ones_like(data) + x_jitter, data, color='lightgray', alpha=0.7)

# --- Overlay horizontal line for mean ---
plt.axhline(mean_val, color='black', linewidth=1.5)

# --- Overlay vertical line for SEM ---
plt.errorbar(1, mean_val, yerr=sem_val, fmt='o', color='black', elinewidth=1.5, capsize=5)

# --- Adjust plot ---
plt.xticks([1], ['Data'])
plt.ylabel('Value')
plt.title('Scatter plot with mean and SEM')

# --- Show plot ---
plt.show()
# Out:
# c:\Users\jrall\miniforge3\envs\sleap_analysis\Lib\site-packages\numpy\_core\fromnumeric.py:4062: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 13
#      11 # --- Scatter plot with jitter ---
#      12 x_jitter = np.random.normal(0, 0.05, size=len(data))  # small horizontal jitter
# ---> 13 plt.scatter(np.ones_like(data) + x_jitter, data, color='lightgray', alpha=0.7)
#      15 # --- Overlay horizontal line for mean ---
#      16 plt.axhline(mean_val, color='black', linewidth=1.5)
#
# ValueError: operands could not be broadcast together with shapes (199,12) (199,)

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.11.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    6.2.0
# Brotli                    1.2.0
# cached-property           1.5.2
# certifi                   2026.1.4
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.3.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# fonttools                 4.60.1
# ...
